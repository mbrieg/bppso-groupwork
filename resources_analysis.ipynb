# %% [markdown]
# # Resource Analysis of the BPIC-17 Event log

# %% [markdown]
# ### Imports and Setup

# %%
import pm4py as pm

# %%
log = pm.read_xes("./data/BPI Challenge 2017.xes.gz")
df = pm.convert_to_dataframe(log)
# Out:
# parsing log, completed traces ::   0%|          | 0/31509 [00:00<?, ?it/s]

# %% [markdown]
# Extract resource related columns

# %% [markdown]
# ## Discovery

# %% [markdown]
# Resource groups

# %% [markdown]
# ## Evaluation

# %% [markdown]
# ### Fitness

# %% [markdown]
# ### Precision

# %% [markdown]
# ## Analysis

# %% [markdown]
# How are Resource Groups involved in process execution?
